# %% [markdown]
# <a href="https://colab.research.google.com/github/tn-220/SIC-Machine-Learning/blob/main/SIC_ML_Coding_Exercises/SIC_ML_Chapter_03_Coding_Exercises/ex_0202.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Coding Exercise #0202

# %% [markdown]
# ### 1. NumPy array operations:

# %% [markdown]
# #### 1.1. '+' and '*' operators for Python lists:

# %%
import numpy as np

# %%
a = [1, 2, 3]

# %%
a + a

# %%
a*3

# %%
b = np.array([1, 2, 3])

# %%
b*3

# %%
b + b

# %%
np.repeat(b, 3)

# %%
np.tile(b,3)

# %%
c = np.arange(30).reshape(5, 6)
print(c)
print(np.tile(c,2))
print(np.repeat(c,2))
print(c.shape)
print(np.tile(c,2).shape)
print(np.repeat(c,2).shape)

# %% [markdown]
# #### 1.2. '+' and '*' operators for NumPy arrays:

# %%
a = np.array([1, 2, 3])
b = np.array([4, 5, 6])

# %%
a+b

# %%
a-b

# %%
a*b

# %%
1.0*a/b

# %% [markdown]
# #### 1.3. Universal functions:

# %%
x = np.array([0, 1, 2, 3, 4, 5])

# %%
np.sqrt(x)

# %%
np.exp(x)

# %%
type(np.sqrt)

# %%
type(np.exp)

# %% [markdown]
# #### 1.4. NumPy functions:

# %%
# np.random.seed(123)
a = np.random.randint(1, 11, size=1000)
# print(a)

# %%
print(np.unique(a))
print(np.unique(a).size)

# %%
np.median(a)

# %%
np.sum(a)

# %%
print(np.var(a))
print(np.round(np.var(a),2))

# %%
np.round(np.mean(a),2)

# %%
np.round(np.std(a),2)

# %%
np.max(a)

# %%
np.min(a)

# %% [markdown]
# #### 1.5. Statistical methods of NumPy arrays:

# %%
x=np.arange(1,11)
print(x)

# %%
x.sum()

# %%
x.mean()

# %%
x.std()

# %%
x.var()

# %%
x.cumsum()

# %%
y = np.arange(1,10)
print(y, "\n")
y = y.reshape((3,-1))
print(y)

# %%
print(y.mean(axis=0))

# %%
print(y.mean(axis=1))

# %%
z = np.random.randint(10,size=1000)

# %%
z.max()

# %%
z.min()

# %%
print((z > 5).sum())
print(type(z > 5))
# print(z > 5)      # This is a mask matrix
print(z[z > 5])

# %%
np.unique(z)

# %%
print(set(z))
print(sorted(set(z)))
print(type(np.unique(z)))
print(type(set(z)))

# %%
a = np.array([2,-3,4,5,7,0,1,-1])
print(a)

# %%
a.argmax()    # Returns the indices of the maximum values along an axis.

# %%
a.argmin()    # Returns the indices of the minimum values along an axis.

# %%
# argwhere() function

in_arr = np.arange(8).reshape(4, 2)     # input array
print ("Input array : \n", in_arr)

out_arr = np.argwhere(in_arr>4)
print ("Output indices greater than 4: \n", out_arr)
