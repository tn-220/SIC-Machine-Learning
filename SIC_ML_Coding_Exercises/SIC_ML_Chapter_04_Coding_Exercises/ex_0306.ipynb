# %% [markdown]
# <a href="https://colab.research.google.com/github/tn-220/SIC-Machine-Learning/blob/main/SIC_ML_Coding_Exercises/SIC_ML_Chapter_04_Coding_Exercises/ex_0306.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Coding Exercise #0306

# %% [markdown]
# ### 1. Interval Estimation of the Proportion:

# %%
import numpy as np
import scipy.stats as st

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
print(f"When Confidence Interval Probability is 0.50 then, the z value is  {st.norm.ppf((1-0.5)/2):.2f} and {-1 * st.norm.ppf((1-0.5)/2):.2f}")
print(f"When Confidence Interval Probability is 0.60 then, the z value is  {st.norm.ppf((1-0.6)/2):.2f} and {-1 * st.norm.ppf((1-0.6)/2):.2f}")
print(f"When Confidence Interval Probability is 0.70 then, the z value is  {st.norm.ppf((1-0.7)/2):.2f} and {-1 * st.norm.ppf((1-0.7)/2):.2f}")
print(f"When Confidence Interval Probability is 0.80 then, the z value is  {st.norm.ppf((1-0.8)/2):.2f} and {-1 * st.norm.ppf((1-0.8)/2):.2f}")
print(f"When Confidence Interval Probability is 0.90 then, the z value is  {st.norm.ppf((1-0.9)/2):.2f} and {-1 * st.norm.ppf((1-0.9)/2):.2f}")
print(f"When Confidence Interval Probability is 0.95 then, the z value is  {st.norm.ppf((1-0.95)/2):.2f} and {-1 * st.norm.ppf((1-0.95)/2):.2f}")
print(f"When Confidence Interval Probability is 0.99 then, the z value is  {st.norm.ppf((1-0.99)/2):.2f} and {-1 * st.norm.ppf((1-0.99)/2):.2f}")

# %% [markdown]
# 1). There are two candidates for the election: A and B.
# The candidate A wants to survey his approval rating.
# Out of 100 suerveyed, 55 answered positively.
# Can A be sure of this election?
# - Assume that A gets elected with 50% or more.
# - Use 95% confidence interval.

# %%
# 95% Confidence Interval.
# We apply the expression for the standard error (SE) from the lecture.
# We ignore additional corrections. 
n_yes = 55
n_total = 100
p_mean = n_yes/n_total
SE = np.sqrt(p_mean*(1-p_mean)/n_total)         # standard error for bernoulli distribution
z = -1 * st.norm.ppf((1-0.95)/2)
print(z)
CL = ((p_mean - z * SE),(p_mean +  z * SE))
print(CL)

# %%
# 95% Confidence Interval.
# We apply the expression for the standard error (SE) from the lecture.
# We ignore additional corrections. 
n_yes = 55
n_total = 100
p_mean = n_yes/n_total
SE = np.sqrt(p_mean*(1-p_mean)/n_total)         # standard error for bernoulli distribution
st.norm.interval(0.95, loc = p_mean, scale=SE)

# %% [markdown]
# *=> The confidence interval has the lower bound below 50%. So A cannot be sure with the confidence level of 95%.*

# %% [markdown]
# 2). Out of 1000 suerveyed, 550 answered positively. Can A be sure of this election?
# - Assume that A gets elected with 50% or more.
# - Use 95% confidence interval.

# %%
# 95% Confidence Interval.
# We apply the expression for the standard error (SE) from the lecture.
# W ignore additional corrections. 
n_yes = 550
n_total = 1000
p_mean = n_yes/n_total
SE = np.sqrt(p_mean*(1-p_mean)/n_total)
st.norm.interval(0.95, loc = p_mean, scale=SE)

# %% [markdown]
# *=> The confidence interval has the lower bound above 50%. So A can be sure with the confidence level of 95%.*
