# %% [markdown]
# <a href="https://colab.research.google.com/github/tn-220/SIC-Machine-Learning/blob/main/SIC_ML_Quizzes/SIC_ML_Chapter_04_Quiz/sol_0305.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Quiz #0305 (Solution)

# %% [markdown]
# ### "Correlation and interval estimation"

# %%
import numpy as np
import scipy.stats as st

# %% [markdown]
# #### Answer the following questions by providing Python code:

# %% [markdown]
# Calculate the 95% and 99% conficence intervals for the Pearson correlation. <br>
# Discuss whether the confidence interval includes zero or not.

# %% [markdown]
# 1). When the sample size $n = 30$ and the sample correlation $r = 0.45$:

# %%
n = 30
r = 0.45
z = np.arctanh(r)
std_error_z = 1/np.sqrt(n-3)
print(std_error_z)

# %%
# 95% confidence interval. 
{'low':np.tanh(z-st.norm.ppf(0.975)*std_error_z), 'high': np.tanh(z+st.norm.ppf(0.975)*std_error_z)}
# We conclude that the confidence interval excludes zero.

# %%
# 99% confidence interval. 
{'low':np.tanh(z-st.norm.ppf(0.995)*std_error_z), 'high': np.tanh(z+st.norm.ppf(0.995)*std_error_z)}
# We conclude that the confidence interval includes zero.
# We conclude that the sample correlation cannot be distinguished from zero.

# %% [markdown]
# 2). When the sample size $n = 300$ and the sample correlation $r = -0.2$:

# %%
n = 300
r = -0.2
z = np.arctanh(r)
std_error_z = 1/np.sqrt(n-3)

# %%
# 95% confidence interval. 
{'low':np.tanh(z-st.norm.ppf(0.975)*std_error_z), 'high': np.tanh(z+st.norm.ppf(0.975)*std_error_z)}
# We conclude that the confidence interval excludes zero.

# %%
# 99% confidence interval. 
{'low':np.tanh(z-st.norm.ppf(0.995)*std_error_z), 'high': np.tanh(z+st.norm.ppf(0.995)*std_error_z)}
# We conclude that the confidence interval excludes zero.

# %% [markdown]
# Confidence interval is the interval that may contain the true value of a population parameter with a given confidence level.
#
# ####Confidence interval of the correlation:

# %% [markdown]
# ![image.png](data:image/png;base64,...)
